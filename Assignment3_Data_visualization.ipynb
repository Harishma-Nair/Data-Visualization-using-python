# %% [markdown]
# <a href="https://colab.research.google.com/github/Harishma-Nair/Data-Visualization-using-python/blob/main/Assignment3_Data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd 
import numpy as np 
import matplotlib as mns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = sns.load_dataset('fmri')

# %%
data.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
data['event'].unique()
# Out:
# array(['stim', 'cue'], dtype=object)

# %%
data['region'].unique()
# Out:
# array(['parietal', 'frontal'], dtype=object)

# %%
data['timepoint'].unique()
# Out:
# array([18, 14, 17,  9, 16, 15,  0, 13, 12, 11, 10,  3,  7,  8,  2,  6,  5,
#         4,  1])

# %%
sns.relplot(x = 'timepoint', y= 'signal', kind = 'line', data = data)

# %%
sns.relplot(x = 'timepoint', y= 'signal', kind = 'scatter', data = data, legend = 'auto')

# %%
sns.catplot(x ='event', y='signal', data = data)

# %%
sns.catplot(x ='event', y='signal', data = data, kind = 'box')

# %%
sns.catplot(x ='event', y='signal', data = data, kind = 'swarm' )
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 21.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 47.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x ='event', y='signal', data = data, kind = 'violin')

# %%
sns.catplot(x ='event', y='signal', data = data, kind = 'boxen')

# %%
sns.catplot(x ='signal', y='event', data = data, kind = 'box', orient= 'horizontal')
